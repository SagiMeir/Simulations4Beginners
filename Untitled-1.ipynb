# %%
from typing import Optional
import numpy as np
import pandas as pd
from scipy.constants import Boltzmann as BOLTZMANN
from scipy.constants import hbar
import matplotlib.pyplot as plt
# and for nice looking plots:
import seaborn as sns
sns.set_theme(style="ticks",rc={'axes.labelsize':14},palette='tab10')

# %%
omega = 7.56E13
print(hbar)

print(hbar*omega*0.5)

print(0.03*hbar/omega)
# Out:
# 1.0545718176461565e-34
# 3.9862814707024715e-21
# 4.184808800183161e-50

# %% [markdown]
# ## PIMD const energy

# %% [markdown]
# 10 Beads

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# and for nice looking plots:
import seaborn as sns
sns.set_theme(style="ticks",rc={'axes.labelsize':14},palette='tab10')

df = pd.read_csv("sim.log",sep='\s+')
x = df["step"].values
plt.plot(x,df["K"].values,label ="K")
plt.plot(x,df["U"].values,label ="U")
plt.plot(x,df["SpringEnergy"].values,label ="SpringEnergy")
plt.plot(x,df["E"].values,label ="TOTAL")
# plt.plot(x,df["SpringEnergy"].values+df["K"].values+df["U"].values)
plt.legend()

plt.xlabel("step[~ 8E-16 sec]")
plt.ylabel("energy")
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\elira\AppData\Local\Temp\ipykernel_20464\462141307.py:8: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("sim.log",sep='\s+')
# Text(0, 0.5, 'energy')

# %% [markdown]
# #### MB distribution test

# %%
from scipy.constants import Boltzmann as BOLTZMANN

# for i in range(100000):
p=(np.random.randn(1000000)*(np.sqrt(BOLTZMANN*298/6.633E-26)))
plt.hist(p,200)
print(np.sqrt(BOLTZMANN*298/6.633E-26))
print(p.std())
print(p)
# Out:
# 249.0547188421383
# 249.21539110193305
# [ 236.73773472  -42.6551267  -102.73517856 ... -209.09041126 -145.72330836
#  -203.60494861]

# %% [markdown]
# ## PIMD const temp

# %%
import numpy as np #8 beads at room temp --working--
import pandas as pd
import matplotlib.pyplot as plt
# and for nice looking plots:
import seaborn as sns
sns.set_theme(style="ticks",rc={'axes.labelsize':14},palette='tab10')

df = pd.read_csv("sim.log",sep='\s+')
x = df["step"].values[5:]
plt.plot(x,df["T"].values[5:],label ="temp")
print((df["T"][100:].values).mean())
plt.legend()
# Out:
# 96.34184815454546
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\elira\AppData\Local\Temp\ipykernel_20464\1918747087.py:8: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("sim.log",sep='\s+')

# %%
from typing import Optional# 16 beads in 96.7 temp - estimator
import numpy as np
import pandas as pd
from scipy.constants import Boltzmann as BOLTZMANN
from scipy.constants import hbar
import matplotlib.pyplot as plt
# and for nice looking plots:
import seaborn as sns

df = pd.read_csv("sim.log",sep='\s+')
x = df["step"].values[50:]
plt.plot(x,df["QE"].values[50:],label ="QE")
print(df["QE"].values[50:].mean())
print(0.5*hbar*7.596E13)
plt.legend()

plt.xlabel("step[0.1E-16 sec]")
plt.ylabel("estimator[J]")
# Out:
# 2.6567472244347825e-21
# 4.005263763420102e-21
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\elira\AppData\Local\Temp\ipykernel_20464\3164329779.py:10: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("sim.log",sep='\s+')
# Text(0, 0.5, 'estimator[J]')

# %%
from typing import Optional
import numpy as np
import pandas as pd
from scipy.constants import Boltzmann as BOLTZMANN
from scipy.constants import hbar
import matplotlib.pyplot as plt
# and for nice looking plots:
import seaborn as sns

# meanQE =[]
# for i in range(2,7):
#     df = pd.read_csv("sim"+str(2**i)+".log",sep='\s+')
#     meanQE.append(df["QE"].values.mean())
# x = [2**i for i in range(2,7)]
# plt.plot(x,meanQE)
# plt.xlabel("beads")
# plt.ylabel("estimator[J]")
df = pd.read_csv("sim.log",sep='\s+')
plt.plot(df["step"].values[50:],df["QE"].values[50:])
print(df["QE"].values[50:].mean())
plt.axhline(df["QE"].values[50:].mean(),color= "red")
# np.sqrt(1)*BOLTZMANN*96.8/hbar


plt.xlabel("step [ 0.1E-16 sec]")
plt.ylabel("estimator [J]")
# Out:
# 2.6567472244347825e-21
# <>:18: SyntaxWarning: invalid escape sequence '\s'
# <>:18: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\elira\AppData\Local\Temp\ipykernel_20464\3040781296.py:18: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("sim.log",sep='\s+')
# Text(0, 0.5, 'estimator [J]')

# %% [markdown]
# test for N beads 2 - 128

# %%
avgQE =[]
amountbeads =[]

for i in range(2,8):
    bead = 2**i
    df = pd.read_csv("C:/Users/elira/OneDrive/Documents/GitHub/Simulations4Beginners/estimator2(better)/sim"+str(bead)+".log",sep='\s+')
    # plt.plot(df["step"].values[50:],df["QE"].values[50:])
    avgQE.append(df["QE"].values[50:].mean())
    amountbeads.append(bead)
plt.plot(amountbeads, avgQE)
plt.axhline(0.5*hbar*7.596E13)#0.5*hbar*7.596E13


plt.xlabel("amount of beads")
plt.ylabel("average estimator")
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\elira\AppData\Local\Temp\ipykernel_20464\693968201.py:6: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("C:/Users/elira/OneDrive/Documents/GitHub/Simulations4Beginners/estimator2(better)/sim"+str(bead)+".log",sep='\s+')
# Text(0, 0.5, 'average estimator')

# %%
from typing import Optional
import numpy as np
import pandas as pd
from scipy.constants import Boltzmann as BOLTZMANN
from scipy.constants import hbar
import matplotlib.pyplot as plt
# and for nice looking plots:
import seaborn as sns
df = pd.read_csv("sim.log",sep='\s+')
plt.plot(df["step"].values[50:],df["T"].values[50:])
print(df["T"].values[50:].mean())

plt.xlabel("step [ 0.1E-16 sec]")
plt.ylabel("temp [K]")
# Out:
# 95.43650267999999
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\elira\AppData\Local\Temp\ipykernel_13548\986447337.py:9: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("sim.log",sep='\s+')
# Text(0, 0.5, 'temp [K]')

# %%
avgQE =[]##אסטימטור לא מאוד טוב
amountbeads =[]

for i in range(2,8):
    bead = 2**i
    df = pd.read_csv("sim"+str(bead)+".log",sep='\s+')
    # plt.plot(df["step"].values[50:],df["QE"].values[50:])
    avgQE.append(df["QE"].values[50:].mean())
    amountbeads.append(bead)
plt.plot(amountbeads, avgQE)
plt.axhline(4.005263763420102e-21)


plt.xlabel("amount of beads")
plt.ylabel("average estimator")
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\elira\AppData\Local\Temp\ipykernel_13548\2570398349.py:6: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("sim"+str(bead)+".log",sep='\s+')
# Text(0, 0.5, 'average estimator')

# %%
df = pd.read_csv("sim.log",sep='\s+')
plt.plot(df["step"].values[50:],df["QE"].values[50:])
print(df["QE"].values[50:].mean())
plt.axhline(df["QE"].values[50:].mean(), color = "red")
plt.axhline(4.005263763420102e-21)
print(df["U"].values[50:].mean()/64)
plt.xlabel("step [0.1E-16]")
plt.ylabel("estimator [J]")
# Out:
# 6.883298146666666e-21
# 2.8514704916666667e-21
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\elira\AppData\Local\Temp\ipykernel_23596\1899109837.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("sim.log",sep='\s+')
# Text(0, 0.5, 'estimator [J]')

# %%
df = pd.read_csv("sim.log",sep='\s+')
plt.plot(df["step"].values[50:200],df["QE"].values[50:200])
plt.axhline(df["QE"].values[50:200].mean())

plt.plot(df["step"].values[200:],df["QE"].values[200:], color = "red")
plt.axhline(df["QE"].values[200:].mean(), color = "red")


plt.xlabel("step [0.1E-16]")
plt.ylabel("estimator [J]")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\elira\AppData\Local\Temp\ipykernel_704\1166641512.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("sim.log",sep='\s+')
# Text(0, 0.5, 'estimator [J]')

# %%
avgQE =[]
avgU =[]
amountbeads =[]

for i in range(2,8):
    bead = 2**i
    df = pd.read_csv("sim"+str(bead)+".log",sep='\s+')
    # plt.plot(df["step"].values[50:],df["QE"].values[50:])
    avgQE.append(df["QE"].values[50:].mean())
    avgU.append(df["U"].values[50:].mean()/bead*2)
    amountbeads.append(bead)
plt.plot(amountbeads, avgQE)
plt.plot(amountbeads, avgU, color = "red")
plt.axhline(4.005263763420102e-21)


plt.xlabel("amount of beads")
plt.ylabel("average estimator")
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\elira\AppData\Local\Temp\ipykernel_704\2430481102.py:7: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("sim"+str(bead)+".log",sep='\s+')
# Text(0, 0.5, 'average estimator')

# %%
df = pd.read_csv("sim.log",sep='\s+')
x = df["step"].values
plt.plot(x,df["K"].values,label ="K")
plt.plot(x,df["U"].values*10**20,label ="U")
#plt.plot(x,df["SpringEnergy"].values,label ="SpringEnergy")
plt.plot(x,df["E"].values,label ="TOTAL")
# plt.plot(x,df["SpringEnergy"].values+df["K"].values+df["U"].values)
plt.legend()#

df = open("sim0.xyz", 'r')

steps= []
pos= []

i = 0
for line in df:
    if (i%3 == 1):
        tmp = line.split()
        steps.append(float(tmp[-1]))
    elif(i%3 == 2):
        tmp = line.split()
        pos.append(float(tmp[1]))
    i+=1
plt.plot(steps,np.array(pos)**2*100,color='tab:green')

df.close()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\elira\AppData\Local\Temp\ipykernel_20464\2357148902.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("sim.log",sep='\s+')

# %%
df = open("sim0.xyz", 'r')

steps= []
pos= []

i = 0
for line in df:
    if (i%3 == 1):
        tmp = line.split()
        steps.append(float(tmp[-1]))
    elif(i%3 == 2):
        tmp = line.split()
        pos.append(float(tmp[1]))
    i+=1

x = min(pos)
print(pos.index(x))

plt.plot(steps,pos,linewidth=0.1)


print(pos)
df.close()
# Out:
# 138
# ...

# %%
# Out:
# 96.70002449138296
